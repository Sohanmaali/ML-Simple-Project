# %%
from ultralytics import YOLO

modal = YOLO("yolo11n.pt")

# train_result = modal.train(
#     data = "dataset/data.yaml",
#     epochs=10,
#     imgsz=250,
#     device="cpu",
# )

# %%
modal = YOLO("runs/detect/train/weights/best.pt")
results = modal("test_images", save=True)

results[0].show()
# Out:
# image 1/12 D:\Sohan\Python\Yolo\test_images\0.jpg: 192x256 (no detections), 25.9ms
# image 2/12 D:\Sohan\Python\Yolo\test_images\1.jpg: 192x256 1 Squirrel, 25.2ms
# image 3/12 D:\Sohan\Python\Yolo\test_images\10.jpg: 256x128 (no detections), 20.9ms
# image 4/12 D:\Sohan\Python\Yolo\test_images\11.jpg: 160x256 1 Squirrel, 24.1ms
# image 5/12 D:\Sohan\Python\Yolo\test_images\2.jpg: 160x256 (no detections), 19.7ms
# image 6/12 D:\Sohan\Python\Yolo\test_images\3.jpg: 192x256 1 Squirrel, 18.1ms
# image 7/12 D:\Sohan\Python\Yolo\test_images\4.jpg: 160x256 1 Squirrel, 19.0ms
# image 8/12 D:\Sohan\Python\Yolo\test_images\5.jpg: 192x256 (no detections), 23.6ms
# image 9/12 D:\Sohan\Python\Yolo\test_images\6.jpg: 192x256 1 Squirrel, 20.3ms
# image 10/12 D:\Sohan\Python\Yolo\test_images\7.jpg: 160x256 1 Squirrel, 18.2ms
# image 11/12 D:\Sohan\Python\Yolo\test_images\8.jpg: 192x256 1 Squirrel, 21.6ms
# image 12/12 D:\Sohan\Python\Yolo\test_images\9.jpg: 192x256 1 Squirrel, 20.4ms
# ...
