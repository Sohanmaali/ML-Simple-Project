# %%
from PIL import Image

# %%
img = Image.open("download.jpg") 
print(img.size)
print(img.info)
print(img.format)
print(img.getpixel)
print(img.filename)
# Out:
# (183, 275)
# {'jfif': 257, 'jfif_version': (1, 1), 'jfif_unit': 0, 'jfif_density': (1, 1)}
# JPEG
# <bound method Image.getpixel of <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=183x275 at 0x1A56F7C2BA0>>
# download.jpg
