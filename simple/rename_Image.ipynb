# %%
import os
import shutil

# Paths
source_folder = 'data'  # folder with original images
destination_folder = 'Squirrel_data'  # folder to save renamed images

# Create destination folder if it doesn't exist
os.makedirs(destination_folder, exist_ok=True)

# List all files in the source folder
files = os.listdir(source_folder)

# Filter only image files (common extensions)
image_extensions = ('.jpg', '.jpeg', '.png', '.bmp', '.gif', '.tiff')
images = [f for f in files if f.lower().endswith(image_extensions)]

# Rename and copy images
for idx, image_name in enumerate(images, start=1):
    ext = os.path.splitext(image_name)[1]  # keep the original extension
    new_name = f'{idx}{ext}'  # rename as 1.jpg, 2.png, ...
    src_path = os.path.join(source_folder, image_name)
    dst_path = os.path.join(destination_folder, new_name)
    shutil.copy2(src_path, dst_path)  # copy the file to destination folder

print(f'Renamed and saved {len(images)} images to {destination_folder}')
# Out:
# Renamed and saved 1095 images to Squirrel_data
